# %%
# Importing Packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing Data
df_mcq = pd.read_csv("../Data/kaggle_multiple_choice.csv")
# Out:
# C:\Users\klmsa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_mcq.head()
# Out:
#   LearningPlatformUsefulnessArxiv LearningPlatformUsefulnessBlogs  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                     Very useful                             NaN
# 3                             NaN                     Very useful
# 4                     Very useful                             NaN
#
#   LearningPlatformUsefulnessCollege LearningPlatformUsefulnessCompany  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                   Somewhat useful                               NaN
# 3                       Very useful                               NaN
# 4                               NaN                               NaN
#
#   LearningPlatformUsefulnessConferences LearningPlatformUsefulnessFriends  \
# ...

# %%
df_mcq.columns
# Out:
# Index(['LearningPlatformUsefulnessArxiv', 'LearningPlatformUsefulnessBlogs',
#        'LearningPlatformUsefulnessCollege',
#        'LearningPlatformUsefulnessCompany',
#        'LearningPlatformUsefulnessConferences',
#        'LearningPlatformUsefulnessFriends', 'LearningPlatformUsefulnessKaggle',
#        'LearningPlatformUsefulnessNewsletters',
#        'LearningPlatformUsefulnessCommunities',
#        'LearningPlatformUsefulnessDocumentation',
#        'LearningPlatformUsefulnessCourses',
#        'LearningPlatformUsefulnessProjects',
#        'LearningPlatformUsefulnessPodcasts', 'LearningPlatformUsefulnessSO',
#        'LearningPlatformUsefulnessTextbook',
#        'LearningPlatformUsefulnessTradeBook',
#        'LearningPlatformUsefulnessTutoring',
#        'LearningPlatformUsefulnessYouTube', 'CurrentJobTitleSelect',
#        'MLMethodNextYearSelect', 'WorkChallengeFrequencyPolitics',
#        'WorkChallengeFrequencyUnusedResults',
# ...

# %% [markdown]
# ### 1. Plot bar chart of CurrentJobTitleSelect

# %%
plt.figure(figsize = (6,6))
df_mcq["CurrentJobTitleSelect"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ### 2. Order by frequency - descending

# %%
df_mcq["CurrentJobTitleSelect"].value_counts().sort_values(ascending=False)
# Out:
# Data Scientist                          2433
# Software Developer/Software Engineer    1759
# Other                                   1233
# Data Analyst                            1213
# Scientist/Researcher                     978
# Business Analyst                         796
# Researcher                               619
# Machine Learning Engineer                617
# Engineer                                 552
# Programmer                               462
# Computer Scientist                       335
# Statistician                             289
# DBA/Database Engineer                    187
# Predictive Modeler                       181
# Data Miner                               118
# Operations Research Practitioner          58
# Name: CurrentJobTitleSelect, dtype: int64

# %% [markdown]
# ### 3. Order by frequency - ascending

# %%
df_mcq["CurrentJobTitleSelect"].value_counts().sort_values(ascending=True)
# Out:
# Operations Research Practitioner          58
# Data Miner                               118
# Predictive Modeler                       181
# DBA/Database Engineer                    187
# Statistician                             289
# Computer Scientist                       335
# Programmer                               462
# Engineer                                 552
# Machine Learning Engineer                617
# Researcher                               619
# Business Analyst                         796
# Scientist/Researcher                     978
# Data Analyst                            1213
# Other                                   1233
# Software Developer/Software Engineer    1759
# Data Scientist                          2433
# Name: CurrentJobTitleSelect, dtype: int64

# %% [markdown]
# ### 4. Replace counts with percentages

# %%
df_mcq["CurrentJobTitleSelect"].value_counts(normalize=True)*100
# Out:
# Data Scientist                          20.566357
# Software Developer/Software Engineer    14.868977
# Other                                   10.422654
# Data Analyst                            10.253593
# Scientist/Researcher                     8.267117
# Business Analyst                         6.728656
# Researcher                               5.232460
# Machine Learning Engineer                5.215554
# Engineer                                 4.666103
# Programmer                               3.905325
# Computer Scientist                       2.831784
# Statistician                             2.442942
# DBA/Database Engineer                    1.580727
# Predictive Modeler                       1.530008
# Data Miner                               0.997464
# Operations Research Practitioner         0.490279
# Name: CurrentJobTitleSelect, dtype: float64

# %% [markdown]
# ### 5. Analyze the mean age by the Job titles.

# %%
df_mcq.groupby("CurrentJobTitleSelect").agg({'Age': ['mean']})
# Out:
#                                             Age
#                                            mean
# CurrentJobTitleSelect
# Business Analyst                      33.350384
# Computer Scientist                    35.133739
# DBA/Database Engineer                 36.693989
# Data Analyst                          31.555742
# Data Miner                            32.991304
# Data Scientist                        33.310287
# Engineer                              34.171846
# Machine Learning Engineer             31.130933
# Operations Research Practitioner      38.357143
# Other                                 36.036424
# Predictive Modeler                    34.785311
# Programmer                            31.735099
# Researcher                            33.814262
# Scientist/Researcher                  35.455394
# Software Developer/Software Engineer  32.833622
# Statistician                          36.944637

# %% [markdown]
# ### 6. Filter for rows where Age and CurrentJobTitleSelect are both not NA.

# %%
df_mcq[(df_mcq["Age"].isna() == False) & (df_mcq["CurrentJobTitleSelect"].isna() == False)]
# Out:
#       LearningPlatformUsefulnessArxiv LearningPlatformUsefulnessBlogs  \
# 3                                 NaN                     Very useful
# 4                         Very useful                             NaN
# 5                                 NaN                             NaN
# 6                     Somewhat useful                 Somewhat useful
# 7                                 NaN                             NaN
# ...                               ...                             ...
# 16702                             NaN                             NaN
# 16703                             NaN                             NaN
# 16709                             NaN                             NaN
# 16712                             NaN                             NaN
# 16715                             NaN                             NaN
#
#       LearningPlatformUsefulnessCollege LearningPlatformUsefulnessCompany  \
# ...

# %% [markdown]
# ### 7. Group the dataset by CurrentJobTitleSelect to create a new variable mean_age, that is the mean age for each Job Title.

# %%
df_mcq["mean_age"] = df_mcq.groupby("CurrentJobTitleSelect").transform('mean')
# Out:
# <ipython-input-11-d33a8ef017a2>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the transforming function.
#   df_mcq["mean_age"] = df_mcq.groupby("CurrentJobTitleSelect").transform('mean')

# %%
df_mcq[["CurrentJobTitleSelect","Age"]]
# Out:
#                   CurrentJobTitleSelect   Age
# 0                 DBA/Database Engineer   NaN
# 1                                   NaN  30.0
# 2                                   NaN  28.0
# 3      Operations Research Practitioner  56.0
# 4                    Computer Scientist  38.0
# ...                                 ...   ...
# 16711                               NaN  24.0
# 16712                        Programmer  25.0
# 16713                               NaN  25.0
# 16714                               NaN  16.0
# 16715                        Programmer  27.0
#
# [16716 rows x 2 columns]

# %% [markdown]
# ### 8. order of the plot to be "Entirely internal", "More internal than external","Approximately half internal and half external", "More external than internal", "Entirely external", "Do not know". Write your observation on nan values

# %%
sns.countplot(x="WorkInternalVsExternalTools", data = df_mcq.fillna("NaN"),
              order = ["NaN","Entirely internal", "More internal than external","Approximately half internal and half external", "More external than internal", "Entirely external", "Do not know"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### There are around 85% of NA values in the WorkInternalVsExternalTools feature
